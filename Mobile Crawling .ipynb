# %% [markdown]
# # crawling the Site

# %%
from crawler import *
# Out:
# C:\Users\hamid.jahani\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
Data=get_data()

# %%
Data
# Out:
#           Price                                            Product  \
# 0    53444000.0  Apple iPhone 13 Pro ZA/A Dual SIM 1TB, 6GB Ram...
# 1    46749000.0  Apple iPhone 13 Pro Max ZA/A Dual SIM 256GB, 6...
# 2    45049000.0  Apple iPhone 13 Pro Max ZA/A Dual SIM 256GB, 6...
# 3    43299000.0  Apple iPhone 13 Pro ZA/A Dual SIM 256GB, 6GB R...
# 4    42079000.0  Samsung Galaxy Z Fold3 5G Single SIM 256GB, 12...
# ..          ...                                                ...
# 135  25529000.0  Samsung Galaxy Z Flip3 5G Single SIM 256GB, 8G...
# 136  24239000.0  Caterpillar S62 Pro Dual SIM 128GB, 6GB Ram Mo...
# 137  24049000.0  Samsung Galaxy Z Flip3 5G Single SIM 128GB, 8G...
# 138  22619000.0  Samsung Galaxy S21 Plus 5G Dual SIM 256GB, 8GB...
# 139  21199000.0  Samsung Galaxy S21 Plus 5G Dual SIM 128GB, 8GB...
#
#                                                  Wi-Fi  \
# 0        Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot
# ...

# %%
#Fix Some Variables
import re
l=[]
for i in Data["اندازه"]:
    m = re.search('^(.+?) اینچ', i)
    if m:
        found = m.group(1)
    l.append(float(found))
    
Data["اندازه"]=l

# %%
#features
Data.columns
# Out:
# Index(['Price', 'Product', 'Wi-Fi', 'ابعاد', 'اقلام همراه گوشی', 'اندازه',
#        'باتری قابل تعویض', 'بلندگو', 'بلوتوث', 'تراشه', 'تراکم پیکسلی',
#        'تعداد رنگ', 'تعداد سیم کارت', 'توضیحات سیم کارت', 'جنس بدنه',
#        'جک 3.5 میلیمتری صدا', 'حافظه داخلی', 'حافظه رم (RAM)', 'حسگرها',
#        'خروجی صدا', 'درگاه ارتباطی', 'دوربین', 'دوربین سلفی', 'دیافراگم',
#        'رادیو', 'رزولوشن', 'رنگ بندی', 'سال تولید', 'سایر قابلیت ها',
#        'سایر قابلیت های دوربین اصلی', 'سایر قابلیت های دوربین سلفی',
#        'سرعت شبکه', 'سرعت فیلمبرداری', 'سیستم عامل', 'شبکه 2G', 'شبکه 3G',
#        'شبکه 4G', 'شبکه های ارتباطی', 'صفحه نمایش لمسی', 'عکاسی پانوراما',
#        'فرمت های پخش موسیقی', 'فرمت های پخش ویدئو', 'فرکانس پردازنده مرکزی',
#        'فلش', 'فناوری فوکوس', 'فناوری محافظت از صفحه نمایش',
#        'فناوری مکان یابی', 'فناوری های ارتباطی', 'قابلیت های نرم افزاری',
#        'لرزشگیر تصویر', 'مشخصات باتری', 'منوی فارسی', 'میزان شارژ پخش آهنگ',
# ...

# %% [markdown]
# # Linear Regression

# %%
Data_machine=Data[['Price', 'Product', 'Wi-Fi','اندازه','تراکم پیکسلی', 'بلوتوث', 'تراشه','جنس بدنه','تعداد سیم کارت','سال تولید','رزولوشن','پردازنده گرافیکی','پردازنده مرکزی']]

# %%
Data_machine.columns=["Price","Product","WIFI","bluetooth","Pixel_density","size","resolution","year","Number_of_SIM_cards"
                      ,"Body_Material","Chip","CPU","GPU"]

# %%
Data_machine.head()
# Out:
#         Price                                            Product  \
# 0  53444000.0  Apple iPhone 13 Pro ZA/A Dual SIM 1TB, 6GB Ram...
# 1  46749000.0  Apple iPhone 13 Pro Max ZA/A Dual SIM 256GB, 6...
# 2  45049000.0  Apple iPhone 13 Pro Max ZA/A Dual SIM 256GB, 6...
# 3  43299000.0  Apple iPhone 13 Pro ZA/A Dual SIM 256GB, 6GB R...
# 4  42079000.0  Samsung Galaxy Z Fold3 5G Single SIM 256GB, 12...
#
#                                                 WIFI  bluetooth  \
# 0      Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot        6.1
# 1      Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot        6.7
# 2      Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot        6.7
# 3      Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot        6.1
# 4  Wi-Fi 802.11 a/b/g/n/ac/6e, Dual-Band, Wi-Fi D...        7.6
#
#                             Pixel_density                         size  \
# 0                    460 پیکسل در هر اینچ           نسخه 5.0، A2DP ،LE
# ...

# %%
from sklearn.linear_model import LinearRegression
from pandas_profiling import ProfileReport

# %%
ProfileReport(Data_machine)
# Out:
# C:\Users\hamid.jahani\Anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# ...

# %%
model = LinearRegression()

# %%
X=Data_machine.drop(["Price","Product"],axis=1)
X = pd.get_dummies(data=X, drop_first=True)
X.head()
# Out:
#    bluetooth  \
# 0        6.1
# 1        6.7
# 2        6.7
# 3        6.1
# 4        7.6
#
#    WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, Dual-band, Wi-Fi Direct, Hotspot   \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Direct, DLNA, hotspot  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-Fi Direct, hotspot  \
# 0                                                  0
# 1                                                  0
# ...

# %%
Y = Data_machine['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=101)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 66)
# (28, 66)
# (112,)
# (28,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# print the intercept
print(model.intercept_)
# Out:
# 1.1565665074873275e+20

# %%
coeff_parameter = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_parameter
# Out:
#                                                      Coefficient
# bluetooth                                          -1.315378e+19
# WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, Dual-band, Wi-F... -7.071898e+18
# WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-F... -6.508954e+18
# WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, Wi-F... -1.393587e+19
# WIFI_Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot -2.110210e+19
# ...                                                          ...
# GPU_8 هسته ای (1 هسته Cortex-X1 و 3 هسته Cortex... -8.716504e+18
# GPU_8 هسته ای (1 هسته Kryo 680 و 3 هسته Kryo 68... -6.662122e+18
# GPU_8 هسته ای (Kryo 260)                           -4.236665e+18
# GPU_8 هسته ای Kryo 585                             -2.154015e+18
# GPU_8 هسته ای Kryo 680                             -1.306230e+19
#
# [66 rows x 1 columns]

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([44220416., 44220416., 42205184., 30523392., 48349184., 30523392.,
#        44220416., 48349184., 24461312., 42205184., 42205184., 30523392.,
#        44220416., 33243136., 30556160., 33243136., 30523392., 42205184.,
#        22003712., 29966336., 44220416., 42205184., 23887872., 36913152.,
#        42205184., 24461312., 44220416., 29966336.])

# %%
import seaborn as sns
sns.regplot(y_test,predictions)
# Out:
# C:\Users\hamid.jahani\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
import statsmodels.api as sm
X_train_Sm= sm.add_constant(X_train)
X_train_Sm= sm.add_constant(X_train)
ls=sm.OLS(y_train,X_train_Sm).fit()
print(ls.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     149.5
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):           4.61e-59
# Time:                        09:05:23   Log-Likelihood:                -1776.4
# No. Observations:                 112   AIC:                             3583.
# Df Residuals:                      97   BIC:                             3624.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ...
